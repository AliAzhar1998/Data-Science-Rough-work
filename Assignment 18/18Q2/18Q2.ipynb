# %% [markdown]
# # Forecasting Problem 1
#
# #### Task:
#
# Forecast the Airline prices. Prepare a document for each model explaining how many dummy variables you have created and RMSE value for each model.
# Finally which model you will use for Forecasting.

# %% [markdown]
# ## Steps:
#
# 1. Import new data set
#     - understand the dataset, look into it.
#     - perform EDA.
#     - check data info and null values.
#     - Explore and Visualize the series
# 2. Partition & Metrics
#     - Partition series
#     - Define Metrics and Predictive accuracy evaluators
# 3. Apply forecasting methods
#     - Model-driven
#         - Classical Model Based
#         - Py-caret based ML models
#     - Data-driven
#         - Moving averages & EWMA
#         - Smoothing Techniques
#         - Auto Regression Models
# 4. Evaluate and Compare Performance
#     - Compare RSME values of all models
# 5. Implement Forecasting model
# 6. Conclusion

# %% [markdown]
# ## Import new dataset

# %%
#load the Basic libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#Load visualization libraries
import seaborn as sns
from matplotlib import pyplot as plt
import statsmodels.graphics.tsaplots as tsa_plots
from matplotlib.patches import Rectangle
# %matplotlib inline

# %%
# Load Time series Libraries
import itertools
import statsmodels.formula.api as smf 
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import Holt
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
raw_data=pd.read_excel('C:/Users/Admin/Documents/Assignments/Assignment 18/18Q2\\CocaCola_Sales_Rawdata.xlsx')
raw_data.head()
# Out:
#   Quarter        Sales
# 0   Q1_86  1734.827000
# 1   Q2_86  2244.960999
# 2   Q3_86  2533.804993
# 3   Q4_86  2154.962997
# 4   Q1_87  1547.818996

# %%
raw_data.tail()
# Out:
#    Quarter   Sales
# 37   Q2_95  4936.0
# 38   Q3_95  4895.0
# 39   Q4_95  4333.0
# 40   Q1_96  4194.0
# 41   Q2_96  5253.0

# %%
data = raw_data.copy()

# %%
data.info() #No Null values
#Note data type of data columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Quarter  42 non-null     object
#  1   Sales    42 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 800.0+ bytes

# %%
data.describe()
# Out:
#              Sales
# count    42.000000
# mean   2994.353308
# std     977.930896
# min    1547.818996
# 25%    2159.714247
# 50%    2782.376999
# 75%    3609.250000
# max    5253.000000

# %% [markdown]
# ##### Visualizing the data

# %%
viz=pd.read_excel('C:/Users/Admin/Documents/Assignments/Assignment 18/18Q2\\CocaCola_Sales_Rawdata.xlsx',
                  header=0,index_col=0,parse_dates=True,squeeze=True)
viz[:6]
# Out:
# Quarter
# Q1_86    1734.827000
# Q2_86    2244.960999
# Q3_86    2533.804993
# Q4_86    2154.962997
# Q1_87    1547.818996
# Q2_87    2104.411995
# Name: Sales, dtype: float64

# %%
#Line plot
sns.set(rc={'figure.figsize':(10,6.18)})
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")
sns.lineplot(data=viz, color='lime')
plt.show()
#There seems to be a upward trend with additive seasonality

# %%
sns.histplot(data=viz, color='mediumorchid')
plt.show() #Passenger count with reference to months

# %%
sns.kdeplot(data=viz, color='fuchsia')
plt.show() #Density Plot

# %%
data['quarters'] = data.Quarter.apply(lambda x : x.split('_')[0])
data['years'] = data.Quarter.apply(lambda x : x.split('_')[1])
data.head()
# Out:
#   Quarter        Sales quarters years
# 0   Q1_86  1734.827000       Q1    86
# 1   Q2_86  2244.960999       Q2    86
# 2   Q3_86  2533.804993       Q3    86
# 3   Q4_86  2154.962997       Q4    86
# 4   Q1_87  1547.818996       Q1    87

# %%
quater_dumies=pd.DataFrame(pd.get_dummies(data.quarters))
data=pd.concat([data,quater_dumies],axis=1)
data.head()
# Out:
#   Quarter        Sales quarters years  Q1  Q2  Q3  Q4
# 0   Q1_86  1734.827000       Q1    86   1   0   0   0
# 1   Q2_86  2244.960999       Q2    86   0   1   0   0
# 2   Q3_86  2533.804993       Q3    86   0   0   1   0
# 3   Q4_86  2154.962997       Q4    86   0   0   0   1
# 4   Q1_87  1547.818996       Q1    87   1   0   0   0

# %%
heatmap_y_month = pd.pivot_table(data=data,values="Sales",index="years",columns="quarters",aggfunc="mean",fill_value=0)
sns.heatmap(heatmap_y_month,annot=True,fmt="g")
plt.title('Heatmap of Sales Count with Year and Quarters')
# Out:
# Text(0.5, 1.0, 'Heatmap of Sales Count with Year and Quarters')

# %%
sns.boxplot(x='quarters',y='Sales',data=data)
# Out:
# <AxesSubplot:xlabel='quarters', ylabel='Sales'>

# %%
sns.boxplot(x='years',y='Sales',data=data)
# Out:
# <AxesSubplot:xlabel='years', ylabel='Sales'>

# %% [markdown]
# ##### Seasonal Decompose plots

# %%
decompose_ts = seasonal_decompose(viz,period=12)

# %%
decompose_ts.plot()
plt.show() # there seems to be some patern in the residue

# %% [markdown]
# ##### ACF and PACF plots

# %%
tsa_plots.plot_acf(viz,lags=12) 
#Autocorrelation Factor >> uptill 6 we have good corr() above +-2 SE [Standard Error]
tsa_plots.plot_pacf(viz,lags=12) 
#Partial Autocorrelation Factor >> only 9 and 11 show some good corr() +-2 SE [Standard Error]
plt.show()

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# #### Transformations

# %%
# adding t values >> new variable 1
data['t']= np.arange(1,data.shape[0]+1)

# %%
# adding t_sqr values >> new variable 2
data['t_sqr'] = data['t']**2

# %%
# adding log_ values >> new variable 3
data['log_sales'] = np.log(data['Sales'])

# %%
data.head()
# Out:
#   Quarter        Sales quarters years  Q1  Q2  Q3  Q4  t  t_sqr  log_sales
# 0   Q1_86  1734.827000       Q1    86   1   0   0   0  1      1   7.458663
# 1   Q2_86  2244.960999       Q2    86   0   1   0   0  2      4   7.716443
# 2   Q3_86  2533.804993       Q3    86   0   0   1   0  3      9   7.837477
# 3   Q4_86  2154.962997       Q4    86   0   0   0   1  4     16   7.675529
# 4   Q1_87  1547.818996       Q1    87   1   0   0   0  5     25   7.344602

# %% [markdown]
# #### Partition & Metrics

# %%
#Partition Series
train = data.iloc[:35]
test = data.iloc[35:]

# %% [markdown]
# ##### RMSE for Predictive Accuracy
# - Model with lowest RMSE is the best

# %%
#performance metrics 
pfm_model_bsd = dict() # For model driven
pfm_data_bsd = dict() # For Data driven

# %% [markdown]
# ## Applying Forecasting Methods
# ### Model Driven

# %% [markdown]
# #### Classical ML Model based Methods

# %%
#Linear Model
linear_model = smf.ols('Sales~t',data=train).fit()
pred_linear =  pd.Series(linear_model.predict(pd.DataFrame(test['t'])))
rmse_linear = mean_squared_error(test.Sales, pred_linear, squared=False) #RMSE Calculation
pfm_model_bsd.update( {'Linear Model' : rmse_linear} )
rmse_linear
# Out:
# 636.5072930351143

# %%
#Exponential
Exp = smf.ols('log_sales~t',data=train).fit()
pred_Exp = pd.Series(Exp.predict(pd.DataFrame(test['t'])))
rmse_Exp = mean_squared_error(test.Sales, pred_Exp, squared=False)
pfm_model_bsd.update( {'Exponential Model' : rmse_Exp} )
rmse_Exp
# Out:
# 4515.811064811282

# %%
#Quadratic 
Quad = smf.ols('Sales~t+t_sqr',data=train).fit()
pred_Quad = pd.Series(Quad.predict(test[["t","t_sqr"]]))
rmse_Quad = mean_squared_error(test.Sales,pred_Quad, squared=False)
pfm_model_bsd.update( {'Quadratic Model' : rmse_Quad} )
rmse_Quad
# Out:
# 511.811731941731

# %%
#Additive seasonality 
add_sea = smf.ols('Sales~Q1+Q2+Q3+Q4',data=train).fit()
pred_add_sea = pd.Series(add_sea.predict(test[['Q1','Q2','Q3','Q4']]))
rmse_add_sea = mean_squared_error(test.Sales,pred_add_sea, squared=False)
pfm_model_bsd.update( {'Additive seasonality' : rmse_add_sea} )
rmse_add_sea
# Out:
# 1861.8704164251737

# %%
#Additive Seasonality Quadratic 
add_sea_Quad = smf.ols('Sales~t+t_sqr+Q1+Q2+Q3+Q4',data=train).fit()
pred_add_sea_quad = pd.Series(add_sea_Quad.predict(test[['Q1','Q2','Q3','Q4','t','t_sqr']]))
rmse_add_sea_quad = mean_squared_error(test.Sales,pred_add_sea_quad, squared=False)
pfm_model_bsd.update( {'Additive Seasonality Quadratic' : rmse_add_sea_quad} )
rmse_add_sea_quad
# Out:
# 309.46413951642813

# %%
#Multiplicative Seasonality
Mul_sea = smf.ols('log_sales~Q1+Q2+Q3+Q4',data = train).fit()
pred_Mult_sea = pd.Series(Mul_sea.predict(test))
rmse_Mult_sea = mean_squared_error(test.Sales,pred_Mult_sea, squared=False)
pfm_model_bsd.update( {'Multiplicative Seasonality' : rmse_Mult_sea} )
rmse_Mult_sea
# Out:
# 4516.300741074347

# %%
#Multiplicative Additive Seasonality 
Mul_Add_sea = smf.ols('log_sales~t+Q1+Q2+Q3+Q4',data = train).fit()
pred_Mult_add_sea = pd.Series(Mul_Add_sea.predict(test))
rmse_Mult_add_sea = mean_squared_error(test.Sales,pred_Mult_add_sea, squared=False)
pfm_model_bsd.update( {'Multiplicative Additive Seasonality ' : rmse_Mult_add_sea} )
rmse_Mult_add_sea
# Out:
# 4515.822756171213

# %%
result_model_bsd = pd.DataFrame(pfm_model_bsd.items(),columns=['MODEL', 'RMSE'])
result_model_bsd.sort_values(by=['RMSE'])
#Additive Seasonality Quadratic has the best values
# We will plot the forcasting in the evaluation part
# Out:
#                                   MODEL         RMSE
# 4        Additive Seasonality Quadratic   309.464140
# 2                       Quadratic Model   511.811732
# 0                          Linear Model   636.507293
# 3                  Additive seasonality  1861.870416
# 1                     Exponential Model  4515.811065
# 6  Multiplicative Additive Seasonality   4515.822756
# 5            Multiplicative Seasonality  4516.300741

# %% [markdown]
# ###### Model Evaluation - Additive Seasonality Quadratic

# %%
data2 = data.copy()
data2.head()
# Out:
#   Quarter        Sales quarters years  Q1  Q2  Q3  Q4  t  t_sqr  log_sales
# 0   Q1_86  1734.827000       Q1    86   1   0   0   0  1      1   7.458663
# 1   Q2_86  2244.960999       Q2    86   0   1   0   0  2      4   7.716443
# 2   Q3_86  2533.804993       Q3    86   0   0   1   0  3      9   7.837477
# 3   Q4_86  2154.962997       Q4    86   0   0   0   1  4     16   7.675529
# 4   Q1_87  1547.818996       Q1    87   1   0   0   0  5     25   7.344602

# %%
data2.columns.values
# Out:
# array(['Quarter', 'Sales', 'quarters', 'years', 'Q1', 'Q2', 'Q3', 'Q4',
#        't', 't_sqr', 'log_sales'], dtype=object)

# %%
data2.drop(['Quarter','Q1', 'Q2', 'Q3', 'Q4','t_sqr', 'log_sales'], axis=1, inplace=True)
data2 = data2[['t', 'years', 'quarters', 'Sales']] 
data1 = data2.copy()
data3 = data2.copy()
data_fnl = data2.copy()
data2.head()
# Out:
#    t years quarters        Sales
# 0  1    86       Q1  1734.827000
# 1  2    86       Q2  2244.960999
# 2  3    86       Q3  2533.804993
# 3  4    86       Q4  2154.962997
# 4  5    87       Q1  1547.818996

# %%
data2["Predicted"] = pd.Series(add_sea_Quad.predict(data[['Q1','Q2','Q3','Q4','t','t_sqr']]))
data2.head()
# Out:
#    t years quarters        Sales    Predicted
# 0  1    86       Q1  1734.827000  1715.011163
# 1  2    86       Q2  2244.960999  2277.750192
# 2  3    86       Q3  2533.804993  2194.873446
# 3  4    86       Q4  2154.962997  1919.651866
# 4  5    87       Q1  1547.818996  1703.261332

# %%
# add a date column in the dataset
data2['Date'] = pd.date_range(start='1986-01-01', end = '1996-07-01', freq = 'Q')
data2.head()
# Out:
#    t years quarters        Sales    Predicted       Date
# 0  1    86       Q1  1734.827000  1715.011163 1986-03-31
# 1  2    86       Q2  2244.960999  2277.750192 1986-06-30
# 2  3    86       Q3  2533.804993  2194.873446 1986-09-30
# 3  4    86       Q4  2154.962997  1919.651866 1986-12-31
# 4  5    87       Q1  1547.818996  1703.261332 1987-03-31

# %%
# line plot - View for the entire dataset _ ASQ
viz2 = data2.loc[:,["Date","Sales","Predicted"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz2, x=viz2.Date, y=viz2.Value,hue="predV/sTrue",palette=["deeppink","lime"])
#There is certain variance in the initial years and final years
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Value'>

# %%
#Line plot - Train V/s Test Plot
data2.Predicted.iloc[:35] = np.nan
data2.Sales.iloc[35:] = np.nan

viz3 = data2.loc[:,["Date","Sales","Predicted"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz3, x=viz3.Date, y=viz3.Value,hue="predV/sTrue",palette=["deeppink","lime"])
#There is large variance from true value
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Value'>

# %% [markdown]
# #### Pycaret ML Model based Methods
# - This is a low code library which is extremely good and fast
# - https://towardsdatascience.com/time-series-forecasting-with-pycaret-regression-module-237b703a0c63

# %%
#we have copied this data from previous case
data1.head()
# Out:
#    t years quarters        Sales
# 0  1    86       Q1  1734.827000
# 1  2    86       Q2  2244.960999
# 2  3    86       Q3  2533.804993
# 3  4    86       Q4  2154.962997
# 4  5    87       Q1  1547.818996

# %%
#Partition Series
train1 = data1.iloc[:35]
test1 = data1.iloc[35:]

# %%
#Initialize setup

# import the regression module
from pycaret.regression import *
# initialize setup
s = setup(data = train1, test_data = test1, target = 'Sales', 
          fold_strategy = 'timeseries', numeric_features = ['years', 't'], 
          fold = 3, transform_target = True, session_id = 123)
# Out:
# <style  type="text/css" >
# #T_5986f_row42_col1,#T_5986f_row56_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_5986f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5986f_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5986f_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_5986f_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5986f_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_5986f_row1_col1" class="data row1 col1" >Sales</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5986f_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_5986f_row2_col1" class="data row2 col1" >(35, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_5986f_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_5986f_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_5986f_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_5986f_row4_col1" class="data row4 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_5986f_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_5986f_row5_col1" class="data row5 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_5986f_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_5986f_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_5986f_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_5986f_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_5986f_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_5986f_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_5986f_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_5986f_row9_col1" class="data row9 col1" >(35, 6)</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_5986f_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_5986f_row10_col1" class="data row10 col1" >(7, 6)</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_5986f_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_5986f_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_5986f_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_5986f_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_5986f_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_5986f_row13_col1" class="data row13 col1" >TimeSeriesSplit</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_5986f_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_5986f_row14_col1" class="data row14 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_5986f_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_5986f_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_5986f_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_5986f_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_5986f_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_5986f_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_5986f_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_5986f_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_5986f_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_5986f_row19_col1" class="data row19 col1" >a787</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_5986f_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_5986f_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_5986f_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_5986f_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_5986f_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_5986f_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_5986f_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_5986f_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_5986f_level0_row24" class="row_h

# %%
best = compare_models(sort = 'RMSE') #Super fast Library
#Best Values for Huber Regression RMSE = 350.2645
# Out:
# <style  type="text/css" >
#     #T_93b47_ th {
#           text-align: left;
#     }#T_93b47_row0_col0,#T_93b47_row0_col1,#T_93b47_row0_col4,#T_93b47_row0_col5,#T_93b47_row0_col6,#T_93b47_row1_col0,#T_93b47_row1_col2,#T_93b47_row1_col3,#T_93b47_row2_col0,#T_93b47_row2_col1,#T_93b47_row2_col2,#T_93b47_row2_col3,#T_93b47_row2_col4,#T_93b47_row2_col5,#T_93b47_row2_col6,#T_93b47_row3_col0,#T_93b47_row3_col1,#T_93b47_row3_col2,#T_93b47_row3_col3,#T_93b47_row3_col4,#T_93b47_row3_col5,#T_93b47_row3_col6,#T_93b47_row4_col0,#T_93b47_row4_col1,#T_93b47_row4_col2,#T_93b47_row4_col3,#T_93b47_row4_col4,#T_93b47_row4_col5,#T_93b47_row4_col6,#T_93b47_row5_col0,#T_93b47_row5_col1,#T_93b47_row5_col2,#T_93b47_row5_col3,#T_93b47_row5_col4,#T_93b47_row5_col5,#T_93b47_row5_col6,#T_93b47_row6_col0,#T_93b47_row6_col1,#T_93b47_row6_col2,#T_93b47_row6_col3,#T_93b47_row6_col4,#T_93b47_row6_col5,#T_93b47_row6_col6,#T_93b47_row7_col0,#T_93b47_row7_col1,#T_93b47_row7_col2,#T_93b47_row7_col3,#T_93b47_row7_col4,#T_93b47_row7_col5,#T_93b47_row7_col6,#T_93b47_row8_col0,#T_93b47_row8_col1,#T_93b47_row8_col2,#T_93b47_row8_col3,#T_93b47_row8_col4,#T_93b47_row8_col5,#T_93b47_row8_col6,#T_93b47_row9_col0,#T_93b47_row9_col1,#T_93b47_row9_col2,#T_93b47_row9_col3,#T_93b47_row9_col4,#T_93b47_row9_col5,#T_93b47_row9_col6,#T_93b47_row10_col0,#T_93b47_row10_col1,#T_93b47_row10_col2,#T_93b47_row10_col3,#T_93b47_row10_col4,#T_93b47_row10_col5,#T_93b47_row10_col6,#T_93b47_row11_col0,#T_93b47_row11_col1,#T_93b47_row11_col2,#T_93b47_row11_col3,#T_93b47_row11_col4,#T_93b47_row11_col5,#T_93b47_row11_col6,#T_93b47_row12_col0,#T_93b47_row12_col1,#T_93b47_row12_col2,#T_93b47_row12_col3,#T_93b47_row12_col4,#T_93b47_row12_col5,#T_93b47_row12_col6,#T_93b47_row13_col0,#T_93b47_row13_col1,#T_93b47_row13_col2,#T_93b47_row13_col3,#T_93b47_row13_col4,#T_93b47_row13_col5,#T_93b47_row13_col6,#T_93b47_row14_col0,#T_93b47_row14_col1,#T_93b47_row14_col2,#T_93b47_row14_col3,#T_93b47_row14_col4,#T_93b47_row14_col5,#T_93b47_row14_col6,#T_93b47_row15_col0,#T_93b47_row15_col1,#T_93b47_row15_col2,#T_93b47_row15_col3,#T_93b47_row15_col4,#T_93b47_row15_col5,#T_93b47_row15_col6,#T_93b47_row16_col0,#T_93b47_row16_col1,#T_93b47_row16_col2,#T_93b47_row16_col3,#T_93b47_row16_col4,#T_93b47_row16_col5,#T_93b47_row16_col6,#T_93b47_row17_col0,#T_93b47_row17_col1,#T_93b47_row17_col2,#T_93b47_row17_col3,#T_93b47_row17_col4,#T_93b47_row17_col5,#T_93b47_row17_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_93b47_row0_col2,#T_93b47_row0_col3,#T_93b47_row1_col1,#T_93b47_row1_col4,#T_93b47_row1_col5,#T_93b47_row1_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_93b47_row0_col7,#T_93b47_row1_col7,#T_93b47_row3_col7,#T_93b47_row4_col7,#T_93b47_row5_col7,#T_93b47_row7_col7,#T_93b47_row8_col7,#T_93b47_row9_col7,#T_93b47_row12_col7,#T_93b47_row13_col7,#T_93b47_row14_col7,#T_93b47_row16_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_93b47_row2_col7,#T_93b47_row6_col7,#T_93b47_row10_col7,#T_93b47_row11_col7,#T_93b47_row15_col7,#T_93b47_row17_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_93b47_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_93b47_level0_row0" class="row_heading level0 row0" >huber</th>
#                         <td id="T_93b47_row0_col0" class="data row0 col0" >Huber Regressor</td>
#                         <td id="T_93b47_row0_col1" class="data row0 col1" >307.0714</td>
#                         <td id="T_93b47_row0_col2" class="data row0 col2" >158955.2634</td>
#                         <td id="T_93b47_row0_col3" class="data row0 col3" >350.2645</td>
#                         <td id="T_93b47_row0_col4" class="data row0 col4" >-0.2920</td>
#                         <td id="T_93b47_row0_col5" class="data row0 col5" >0.1309</td>
#                         <td id="T_93b47_row0_col6" class="data row0 col6" >0.1061</td>
#                         <td id="T_93b47_row0_col7" class="data row0 col7" >0.0133</td>
#             </tr>
#             <tr>
#                         <th id="T_93b47_level0_row1" class="row_heading level0 row1" >gbr</th>
#                         <td id="T_93b47_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#                         <td id="T_93b47_row1_col1" class="data row1 col1" >299.7615</td>
#                         <td id="T_93b47_row1_col2" class="data row1 col2" >167676.6230</td>
#                         <td id="T_93b47_row1_col3" class="data row1 col3" >403.7827</td>
#                         <td id="T_93b47_row1_col4" class="data row1 col4" >-0.1156</td>
#                         <td id="T_93b47_row1_col5" class="data row1 col5" >0.1305</td>
#                         <td id="T_93b47_row1_col6" class="data row1 col6" >0.0928</td>
#                         <td id="T_93b47_row1_col7" class="data row1 col7" >0.0133</td>
#             </tr>
#             <tr>
#                         <th id="T_93b47_level0_row2" class="row_heading level0 row2" >dt</th>
#                         <td id="T_93b47_row2_col0" class="data row2 col0" >Decision Tree Regressor</td>
#                         <td id="T_93b47_row2_col1" class="data row2 col1" >324.9201</td>
#                         <td id="T_93b47_row2_col2" class="data row2 col2" >177179.8881</td>
#                         <td id="T_93b47_row2_col3" class="data row2 col3" >412.0147</td>
#                         <td id="T_93b47_row2_col4" class="data row2 col4" >-0.1376</td>
#                         <td id="T_93b47_row2_col5" class="data row2 col5" >0.1332</td>
#                         <td id="T_93b47_row2_col6" class="data row2 col6" >0.1008</td>
#                         <td id="T_93b47_row2_col7" class="data row2 col7" >0.0067</td>
#             </tr>
#             <tr>
#                         <th id="T_93b47_level0_row3" class="row_heading level0 row3" >br</th>
#                         <td id="T_93b47_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#                         <td id="T_93b47_row3_col1" class="data row3 col1" >358.4199</td>
#                         <td id="T_93b47_row3_col2" class="data row3 col2" >184113.4097</td>
#                         <td id="T_93b47_row3_col3" class="data row3 col3" >413.8704</td>
#                         <td id="T_93b47_row3_col4" class="data row3 col4" >-0.4449</td>
#                         <td id="T_93b47_row3_col5" class="data row3 col5" >0.1485</td>
#                         <td id="T_93b47_row3_col6" class="data row3 col6" >0.1197</td>
#                         <td id="T_93b47_row3_col7" class="data row3 col7" >0.0100</td>
#             </tr>
#             <tr>
#                         <th id="T_93b47_level0_row4" class="row_heading level0 row4" >ridge</th>
#                         <td id="T_93b47_row4_col0" class="data row4 col0" >Ridge Regression</td>
#                         <td id="T_93b47_row4_col1" class="data row4 col1" >361.2944</td>
#                         <td id="T_93b47_row4_col2" class="data row4 col2" >185395.6094</td>
#                         <td id="T_93b47_row4_col3" class="data row4 col3" >415.3162</td>
#                         <td id="T_93b47_row4_col4" class="data row4 col4" >-0.4618</td>
#                         <td id="T_93b47_row4_col5" class="data row4 col5" >0.1502</td>
#                         <td id="T_93b47_row4_col6" class="data row4 co

# %%
prediction_holdout = predict_model(best)
# Out:
# <style  type="text/css" >
# </style><table id="T_9f0a2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9f0a2_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9f0a2_row0_col0" class="data row0 col0" >Huber Regressor</td>
#                         <td id="T_9f0a2_row0_col1" class="data row0 col1" >113.8057</td>
#                         <td id="T_9f0a2_row0_col2" class="data row0 col2" >30294.5366</td>
#                         <td id="T_9f0a2_row0_col3" class="data row0 col3" >174.0533</td>
#                         <td id="T_9f0a2_row0_col4" class="data row0 col4" >0.8742</td>
#                         <td id="T_9f0a2_row0_col5" class="data row0 col5" >0.0342</td>
#                         <td id="T_9f0a2_row0_col6" class="data row0 col6" >0.0244</td>
#             </tr>
#     </tbody></table>

# %%
# generate predictions on the original dataset
predictions = predict_model(best, data=data1)
predictions.head()
# Out:
#    t years quarters        Sales        Label
# 0  1    86       Q1  1734.827000  1575.795937
# 1  2    86       Q2  2244.960999  1916.533205
# 2  3    86       Q3  2533.804993  1892.576027
# 3  4    86       Q4  2154.962997  1779.082826
# 4  5    87       Q1  1547.818996  1709.488701

# %%
# add a date column in the dataset
predictions['Date'] = pd.date_range(start='1986-01-01', end = '1996-07-01', freq = 'Q')
data_ma = predictions.copy()
data4 =  predictions.copy()
predictions.head()
# Out:
#    t years quarters        Sales        Label       Date
# 0  1    86       Q1  1734.827000  1575.795937 1986-03-31
# 1  2    86       Q2  2244.960999  1916.533205 1986-06-30
# 2  3    86       Q3  2533.804993  1892.576027 1986-09-30
# 3  4    86       Q4  2154.962997  1779.082826 1986-12-31
# 4  5    87       Q1  1547.818996  1709.488701 1987-03-31

# %%
# line plot - View for the entire dataset

viz1 = predictions.loc[:,["Date","Sales","Label"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz1, x=viz1.Date, y=viz1.Value,hue="predV/sTrue",palette=["aqua","red"])
#Lesser Variance as compared to previous case
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Value'>

# %%
# line plot - View for Train vs test

predictions.Label.iloc[:35] = np.nan
predictions.Sales.iloc[35:] = np.nan

viz4 = predictions.loc[:,["Date","Sales","Label"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz4, x=viz4.Date, y=viz4.Value,hue="predV/sTrue",palette=["aqua","red"])
#Lesser Variance compared to previous cases
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Value'>

# %% [markdown]
# ### Data Driven Forecasting Techniques
#
# #### Moving Averages

# %%
#Make seperate dataset

data_ma = data_ma.set_index('Date')

#Simple Moving Average SMA
data_ma['3-month-SMA'] = data_ma['Sales'].rolling(window=3).mean()
data_ma['6-month-SMA'] = data_ma['Sales'].rolling(window=6).mean()
data_ma['12-month-SMA'] = data_ma['Sales'].rolling(window=12).mean()

# %%
sns.lineplot(data=data_ma[['3-month-SMA','6-month-SMA','12-month-SMA']],palette=["deeppink","lime","aqua"]) #SMA Plot
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#for 3-Months only since it will have the lowest SMA
data_ma['3-month-SMA']=data_ma['3-month-SMA'].fillna(0)
rmse_SMA_3Months = mean_squared_error(data_ma.Sales,data_ma['3-month-SMA'], squared=False)
pfm_data_bsd.update({'SMA-3Months':rmse_SMA_3Months}) 
rmse_SMA_3Months
# Out:
# 530.974317734843

# %%
#Exponentially Weighted Moving Average EWMA
data_ma['EWMA3'] = data_ma['Sales'].ewm(span=3,adjust=True).mean() #3month Span

#Line Plot EWMA
sns.lineplot(data=data_ma[["Sales","EWMA3"]],palette=["deeppink","lime"]) #SMA Plot
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#for 3-Months only since it will have the lowest EWMA
data_ma['EWMA3'] =data_ma['EWMA3'] .fillna(0)
rmse_EWMA3 = mean_squared_error(data_ma.Sales,data_ma['EWMA3'] , squared=False)
pfm_data_bsd.update({'EWMA 3Months':rmse_EWMA3}) 
rmse_EWMA3 #This is a low value but it alone cannot be taken
# Out:
# 199.4860437981679

# %% [markdown]
# #### Smoothing Techniques

# %%
#Simple Exponential Method
ses_model = SimpleExpSmoothing(train["Sales"]).fit(smoothing_level=0.2)
pred_ses = ses_model.predict(start = test.index[0],end = test.index[-1])
rmse_SES = mean_squared_error(test.Sales,pred_ses, squared=False)
pfm_data_bsd.update({'SES':rmse_SES}) 
rmse_SES
# Out:
# 922.9178308307818

# %%
# Holt method 
hw_model = Holt(train["Sales"]).fit(smoothing_level=0.8, smoothing_slope=0.2)
pred_hw = hw_model.predict(start = test.index[0],end = test.index[-1])
rmse_Holt = mean_squared_error(test.Sales,pred_hw, squared=False)
pfm_data_bsd.update({'Holt':rmse_Holt}) 
rmse_Holt
# Out:
# 796.7270706021932

# %%
#Holts winter exponential smoothing with additive seasonality and additive trend
hwe_model_add_add = ExponentialSmoothing(train["Sales"],seasonal="add",trend="add",seasonal_periods=12).fit() #add the trend to the model
pred_hwe_add_add = hwe_model_add_add.predict(start = test.index[0],end = test.index[-1])
rmse_hwe_add = mean_squared_error(test.Sales,pred_hwe_add_add, squared=False)
pfm_data_bsd.update({'HWE Add. Seas & Add. Trend':rmse_hwe_add}) 
rmse_hwe_add
# Out:
# 270.0779086581699

# %%
#Holts winter exponential smoothing with multiplicative seasonality and additive trend
hwe_model_mul_add = ExponentialSmoothing(train["Sales"],seasonal="mul",trend="add",seasonal_periods=12).fit() 
pred_hwe_mul_add = hwe_model_mul_add.predict(start = test.index[0],end = test.index[-1])
rmse_hwe_mul = mean_squared_error(test.Sales,pred_hwe_mul_add, squared=False)
pfm_data_bsd.update({'HWE Mul. Seas & Add. Trend':rmse_hwe_mul}) 
rmse_hwe_mul #Very good value
# Out:
# 129.2574612883441

# %%
pfm_data_bsd
# Out:
# {'SMA-3Months': 530.974317734843,
#  'EWMA 3Months': 199.4860437981679,
#  'SES': 922.9178308307818,
#  'Holt': 796.7270706021932,
#  'HWE Add. Seas & Add. Trend': 270.0779086581699,
#  'HWE Mul. Seas & Add. Trend': 129.2574612883441}

# %%
result_data_bsd = pd.DataFrame(pfm_data_bsd.items(),columns=['MODEL', 'RMSE'])
result_data_bsd.sort_values(by=['RMSE'])
#Lowest RSME values are for HWE Multiplicative Seasonality and Additive Trend
# Out:
#                         MODEL        RMSE
# 5  HWE Mul. Seas & Add. Trend  129.257461
# 1                EWMA 3Months  199.486044
# 4  HWE Add. Seas & Add. Trend  270.077909
# 0                 SMA-3Months  530.974318
# 3                        Holt  796.727071
# 2                         SES  922.917831

# %% [markdown]
# ###### Model Evaluation - HWE Multiplicative Seasonality and Additive Trend

# %%
hwe_mul_model = hwe_model_mul_add.predict(start = data.index[0],end = data.index[-1])
data3['predicted'] = hwe_mul_model
data3.head()
# Out:
#    t years quarters        Sales    predicted
# 0  1    86       Q1  1734.827000  1791.544872
# 1  2    86       Q2  2244.960999  2122.596467
# 2  3    86       Q3  2533.804993  2344.352626
# 3  4    86       Q4  2154.962997  2196.416747
# 4  5    87       Q1  1547.818996  1822.266507

# %%
# add a date column in the dataset
data3['Date'] = pd.date_range(start='1986-01-01', end = '1996-07-01', freq = 'Q')
data3.head()
# Out:
#    t years quarters        Sales    predicted       Date
# 0  1    86       Q1  1734.827000  1791.544872 1986-03-31
# 1  2    86       Q2  2244.960999  2122.596467 1986-06-30
# 2  3    86       Q3  2533.804993  2344.352626 1986-09-30
# 3  4    86       Q4  2154.962997  2196.416747 1986-12-31
# 4  5    87       Q1  1547.818996  1822.266507 1987-03-31

# %%
# line plot - View for the entire dataset _ ASQ
viz5 = data3.loc[:,["Date","Sales","predicted"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz5, x=viz5.Date, y=viz5.Value,hue="predV/sTrue",palette=["deeppink","lime"])
#THe model has the best RMSE value
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Value'>

# %%
#Line plot - Train V/s Test Plot
data3.predicted.iloc[:35] = np.nan
data3.Sales.iloc[35:] = np.nan

viz6 = data3.loc[:,["Date","Sales","predicted"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz6, x=viz6.Date, y=viz6.Value,hue="predV/sTrue",palette=["deeppink","lime"])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Value'>

# %% [markdown]
# #### Auto Regression Models
# - Our data has both trend and Seasonality.
# - Very less chance for it to be stationary data.
# - We will perform AD-Fuller test to determine stationarity.
# - We will observe the ACF and PACF plots to determine suitable Lags.
# - After that, we will perform LL test on each model to determine best values
# ##### AD-Fuller stationarity test

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(series):    
    result = adfuller(series.dropna())  
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)
    #for key,val in result[4].items():
        #out[f'critical value ({key})']=val
    if result[1] <= 0.05:
        print("Reject the null hypothesis")
        print("Data is stationary")
    else:
        print("Fail to reject the null hypothesis")
        print("Data is non-stationary")

# %%
data4=data4.set_index('Date')
data4.head()
# Out:
#             t years quarters        Sales        Label
# Date
# 1986-03-31  1    86       Q1  1734.827000  1575.795937
# 1986-06-30  2    86       Q2  2244.960999  1916.533205
# 1986-09-30  3    86       Q3  2533.804993  1892.576027
# 1986-12-31  4    86       Q4  2154.962997  1779.082826
# 1987-03-31  5    87       Q1  1547.818996  1709.488701

# %%
#AD- Fuller test
adf_test(data4[['Sales']]) #As expected, data is non stationary
#We might need to use SARIMA test in this case
# Out:
# Fail to reject the null hypothesis
# Data is non-stationary

# %%
#ACF and PACF Plots
tsa_plots.plot_acf(viz,lags=12) 
#Autocorrelation Factor >> uptill 6 we have good corr() above +-2 SE [Standard Error]
tsa_plots.plot_pacf(viz,lags=12) 
#Partial Autocorrelation Factor >> only 9 and 11 show some good corr() +-2 SE [Standard Error]
plt.show()

# %%
# We will run a auto arima to determine the ARIME orders
from pmdarima import auto_arima # for determining ARIMA orders
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-71-a0b050cccb31> in <module>
#       1 # We will run a auto arima to determine the ARIME orders
# ----> 2 from pmdarima import auto_arima # for determining ARIMA orders
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
stepwise_fit = auto_arima(data4.Sales, start_p=0, start_q=0,
                          max_p=12, max_q=12, m=12,
                          seasonal=False,
                          d=None, trace=True,
                          error_action='ignore',   # we don't want to know if an order does not work
                          suppress_warnings=True,  # we don't want convergence warnings
                          stepwise=True)           # set to stepwise

stepwise_fit.summary()

# %%
#Fitting a model
from statsmodels.tsa.arima_model import ARIMA

model_arima = ARIMA(train['Sales'],order=(4,1,0))
results = model_arima.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Sales   No. Observations:                   34
# Model:                 ARIMA(4, 1, 0)   Log Likelihood                -226.383
# Method:                       css-mle   S.D. of innovations            173.547
# Date:                Sun, 20 Feb 2022   AIC                            464.765
# Time:                        22:05:25   BIC                            473.923
# Sample:                             1   HQIC                           467.888
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            61.5081     33.777      1.821      0.069      -4.694     127.710
# ar.L1.D.Sales    -0.1806      0.135     -1.339      0.181      -0.445       0.084
# ar.L2.D.Sales    -0.2311      0.141     -1.639      0.101      -0.507       0.045
# ar.L3.D.Sales    -0.1456      0.150     -0.971      0.332      -0.440       0.148
# ar.L4.D.Sales     0.7209      0.145      4.986      0.000       0.438       1.004
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0558           -0.0000j            1.0558           -0.5000
# AR.2           -0.0089           -1.0149j            1.0149           -0.2514
# AR.3           -0.0089           +1.0149j            1.0149            0.2514
# AR.4            1.2756           -0.0000j            1.2756           -0.0000
# -----------------------------------------------------------------------------
# """

# %%
pred_arima = results.predict(start=35, end=len(data4)-1, dynamic=False, typ='levels')

# %%
#RMSE score of ARIMA
rmse_arima= mean_squared_error(test.Sales,pred_arima, squared=False)
rmse_arima #This value is okay but we will not use it sine we have much better models
# Out:
# 134.34031484785515

# %% [markdown]
# ## Evaluate and Compare Performance
# - Best model we have got so far is the Huber Regressor from PyCaret
# - We will build our final model based on this one

# %% [markdown]
# ## Implementing Forecasting Model

# %%
#Holts winter exponential smoothing with multiplicative seasonality and additive trend
final_model = ExponentialSmoothing(data_fnl["Sales"],seasonal="mul",trend="add",seasonal_periods=12).fit() 
pred_final = final_model.predict(start = data.index[0],end = data.index[-1])

#Getting RMSE Score
rmse_final = mean_squared_error(data.Sales,pred_final, squared=False)
rmse_final #This score is good
# Out:
# 154.65045948427777

# %%
data_fnl.head()
# Out:
#    t years quarters        Sales
# 0  1    86       Q1  1734.827000
# 1  2    86       Q2  2244.960999
# 2  3    86       Q3  2533.804993
# 3  4    86       Q4  2154.962997
# 4  5    87       Q1  1547.818996

# %%
data_fnl['final_pred']=pred_final
data_fnl.head()
# Out:
#    t years quarters        Sales   final_pred
# 0  1    86       Q1  1734.827000  1751.064582
# 1  2    86       Q2  2244.960999  2141.909936
# 2  3    86       Q3  2533.804993  2333.029922
# 3  4    86       Q4  2154.962997  2243.157448
# 4  5    87       Q1  1547.818996  1906.522788

# %%
data_fnl['Date'] = pd.date_range(start='1986-01-01', end = '1996-07-01', freq = 'Q')
data_fnl.head()
# Out:
#    t years quarters        Sales   final_pred       Date
# 0  1    86       Q1  1734.827000  1751.064582 1986-03-31
# 1  2    86       Q2  2244.960999  2141.909936 1986-06-30
# 2  3    86       Q3  2533.804993  2333.029922 1986-09-30
# 3  4    86       Q4  2154.962997  2243.157448 1986-12-31
# 4  5    87       Q1  1547.818996  1906.522788 1987-03-31

# %%
# line plot - View for the entire dataset FInal Model
viz8 = data_fnl.loc[:,["Date","Sales","final_pred"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz8, x=viz8.Date, y=viz8.Value,hue="predV/sTrue",palette=["deeppink","lime"])
#Good model but since we have limited dataset, values are less to improve accuracy
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Value'>

# %%
#Forecasting the future
future = pd.DataFrame(final_model.forecast(8)).reset_index()
future.rename(columns={'index':'t',0:'Forecast'},inplace=True)
future.head()
# Out:
#     t     Forecast
# 0  42  4929.498608
# 1  43  4614.623753
# 2  44  4554.130175
# 3  45  5773.661620
# 4  46  5819.106671

# %%
#Creating Forecast dataset
forecast_df= pd.concat([data_fnl,future], axis=0)
forecast_df.drop('Date',axis=1)
forecast_df['Date']=pd.date_range(start='1986-01-01', end = '1998-09-01', freq = 'Q')
forecast_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   t           50 non-null     int64
#  1   years       42 non-null     object
#  2   quarters    42 non-null     object
#  3   Sales       42 non-null     float64
#  4   final_pred  42 non-null     float64
#  5   Date        50 non-null     datetime64[ns]
#  6   Forecast    8 non-null      float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 3.1+ KB

# %%
#Future Forecast

viz9 = forecast_df.loc[:,["Date","Sales","Forecast"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz9, x=viz9.Date, y=viz9.Value,hue="predV/sTrue",palette=["deeppink","lime"])
#Best internal forecast so far
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Value'>

# %% [markdown]
# ## Conclusion
# - We have explored all the possible forecasting techniques.
# - We have built our final model from HWE Multiplicative Seasonality and Additive Trend
# - Forecasting for eight quarters has been plotted.
# - If RMSE was not the metric of usage, We could have gone for Gradient Boosting in PyCaret
